# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("E-Commerce.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)

# %%
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %%
ECom_Data.shape
# Out:
# (8906, 17)

# %% [markdown]
# - There are 8906 rows and 17 columns in the dataset.

# %% [markdown]
# Different methods to print number of rows and columns of the dataset
# - Shape method i.e. **.shape**, which is used in above cell.
# - length function and columns method i.e. **len(), .columns** on dataset to find out number of rows and columns.
# - Numpy method i.e **np.shape** provides number of rows and columns
# - Info function i.e. **info()** on dataset to have more information including number of rows and columns.

# %%
len(ECom_Data), len(ECom_Data.columns)
# Out:
# (8906, 17)

# %%
np.shape(ECom_Data)
# Out:
# (8906, 17)

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# #### Ans  1 c)

# %%
len(ECom_Data.select_dtypes(include='object').columns)
# Out:
# 14

# %% [markdown]
# - There are 14 object data type columns in dataset.
#     - Use select_dtypes() function with 'include' parameter to specify paritcular type of columns only.
#     - len() function to count number of object type columns

# %%
# one more way of finding object columns

len(ECom_Data.loc[:,ECom_Data.dtypes==object].columns)
# Out:
# 14

# %% [markdown]
# ### Ans 1 d)

# %%
len(ECom_Data.select_dtypes(include='bool').columns)
# Out:
# 0

# %% [markdown]
# - There is no boolean data type in the dataset. 'bool' is the data type for Boolean.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
ECom_Data.drop(['product_specifications','description'], axis=1, inplace=True)

ECom_Data.columns
# Out:
# Index(['Customer_uniq_id', 'Region', 'Order_Date', 'Expected_Delivery_Date',
#        'Delivered_Date', 'product_name', 'product_main_category',
#        'product_subcategory', 'product_category_filter',
#        'product_category_subfilter', 'product_unique ID', 'retail_price',
#        'discounted_price', 'product_rating', 'Brand'],
#       dtype='object')

# %% [markdown]
# - From the above cell, we have dropped columns 'product_specifications', 'description' permanently from dataset.
# - After printing ECom_Data.columns, we can verify that the dropped columns are no longer available to us.

# %% [markdown]
# - **Del** method is also used to drop/delete columns from the dataset.

# %% [markdown]
# ### Ans 2 b)

# %% [markdown]
# **Drop function**
#
# Code - **ECom_Data.drop(['product_specifications','description'], axis=1, inplace=True)**
#
# - Drop() function is used to drop/delete the columns from the dataset.
# - To drop permanently, we use inplace=True parameter. By default it's set to False
# - Axis=1 is another parameter to be mentioned explicitly due to python always thinks in row-wise (by default axis=0). So for doing any change column-wise then we should set this parameter.
# - If there are more than 1 column to be dropped then we need to pass them inside a list.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
ECom_Data.Brand.nunique()
# Out:
# 2484

# %% [markdown]
# - There are 2484 unique brands available in the dataset.

# %% [markdown]
# ### Ans 3 b)

# %%
ECom_Data.groupby('Brand').mean()['product_rating'].sort_values(ascending=False)
# Out:
# Brand
#  TARKAN                   5.0
# INDIANO                   5.0
# PUMPKIN PATCH             5.0
# PURE SOURCE               5.0
# BRAHAAN BLUE TAG          5.0
#                          ...
# BRIGHT HOME APPLIANCES    1.0
# TWIN TWINE                1.0
# BRECKEN PAUL              1.0
# QUENELL                   1.0
# FIRANGI                   1.0
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# - From above we can find the average product rating for each brand.

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %% [markdown]
# ### Ans 4 a)

# %%
plt.figure(figsize=(25,10))
plt.title('Product Category type',fontsize=20)
plt.xlabel('Products Categories', fontsize=20)
plt.ylabel('Frequency of products', fontsize=20)
sns.barplot(x=ECom_Data.product_main_category.value_counts().index, y=ECom_Data.product_main_category.value_counts().values, order=ECom_Data.product_main_category.value_counts().index)
plt.xticks(rotation=90, fontsize=18)
plt.yticks(fontsize=15);

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# - Maximum Products ordered category - **Clothing**
# - Minimum Products ordered category - **Wearable Smart Devices**

# %% [markdown]
# ### Ans 4 c)

# %%
ECom_Data.product_main_category.value_counts()[:5]
# Out:
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: product_main_category, dtype: int64

# %% [markdown]
# - Here are the Top 5 Main categories of Products that were ordered frequently.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
def charges(price):
    if price >600:
        return (price*25)/100
    elif price >350 and price <=600:
        return (price*15)/100
    elif price >100 and price <=350:
        return (price*10)/100
    else:
        return (price*5)/100

# %% [markdown]
# - Above user-defined function called 'charges' will take 1 parameter as input i.e. price of the item and then calculates the charges applied according to the item price.

# %%
ECom_Data['Revenue'] = ECom_Data.discounted_price.apply(charges)

ECom_Data.Revenue.sum()
# Out:
# 2217486.85

# %% [markdown]
# - Total Revenue generated by the E-Commerce company over all orders placed is 22,17,486.85

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
ECom_Data['Brand_Revenue'] = ECom_Data.discounted_price - ECom_Data.Revenue

ECom_Data.groupby('Brand').sum().sort_values(by='Brand_Revenue', ascending=False)['Brand_Revenue'][:10]
# Out:
# Brand
# ALLURE AUTO     498464.25
# GAGA            237390.00
# SLIM            212062.60
# DAILYOBJECTS    181980.00
# DIVINITI        143115.00
# THELOSTPUPPY    127287.50
# REGULAR         126536.50
# ENTHOPIA        123146.25
# ASUS             99241.50
# SPRINGWEL        88978.50
# Name: Brand_Revenue, dtype: float64

# %% [markdown]
# - Above are the listed top 10 Brands having maximum brand revenue in descending order.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
plt.figure(figsize=(15,10))
plt.title('Boxplots: Retail Price vs Discounted Price')
sns.boxplot(data=ECom_Data[['retail_price', 'discounted_price']])
plt.xlabel('Distribution of Retail Price and Discounted Price')
plt.ylabel('Price Distribution');

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# - Yes, there are many outliers in both Retail Price distribution and Discounted Price distribution.

# %% [markdown]
# ### Ans 7 c)

# %%
plt.figure(figsize=(15,7))
plt.title('Relation between Retail Price vs Discounted Price')
sns.scatterplot(x=ECom_Data.retail_price, y=ECom_Data.discounted_price, color='g')
plt.xlabel('Retail Price')
plt.ylabel('Discounted Price');

# %% [markdown]
# - Scatterplot shows a **positive correlation** between Retail Price and Discounted Price

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %%
Brand_df = ECom_Data.groupby('Brand').agg({'Brand':['count'], 'retail_price':['sum'], 'discounted_price':['sum'],'Brand_Revenue':['sum']})

Brand_df.columns = ['_'.join(col).strip() for col in Brand_df.columns.values]

Brand_df
# Out:
#              Brand_count  retail_price_sum  discounted_price_sum  \
# Brand
# 1OAK                   2              1698                  1274
# 3A AUTOCARE           41            107059                 74134
# 3D MAT                 1              7250                  6999
# 3KFACTORY              1               399                   174
# 4D                     5             17500                  7948
# ...                  ...               ...                   ...
# ZORDEN                 1              3999                  2799
# ZOSIGN                 5              6995                  6995
# ZRESTHA                1              1999                   899
# ZYXEL                  9             64742                 35392
#  TARKAN                1              1999                   349
#
#              Brand_Revenue_sum
# Brand
# 1OAK                   1015.40
# 3A AUTOCARE           55647.90
# 3D MAT                 5249.25
# 3KFACTORY               156.60
# ...

# %% [markdown]
# - The reason for using groupby on 'Brand' is that we don't have number of orders placed by each brand info. Firstly, we need to perform 'group by' and then provide columns and function explicitly like,
#     - 'Brand' : ['count'],
#     - 'retail_price' : ['sum'],
#     - 'discounted_price' : ['sum'],
#     - 'Brand_Revenue' : ['sum']

# %%
sns.pairplot(Brand_df)
plt.show()

# %% [markdown]
# **Few Insights from Pairplot**
# - Strong Positive correlation between **Discounted Price Sum vs Brand Revenue Sum**.
# - The relation for **Retail Price Sum** with **Brand Revenue Sum and Discounted Price Sum** is very similar from plots.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
ECom_Data_copy = ECom_Data.copy()

# %% [markdown]
# - Copying the data into a new dataframe because few modifications are required. Hence for not effecting primary dataframe, we can use copy() method and do modifications.

# %%
ECom_Data_copy.Order_Date = pd.to_datetime(ECom_Data_copy.Order_Date, infer_datetime_format=True)

ECom_Data_copy['month_year'] = ECom_Data_copy.Order_Date.dt.strftime('%b-%Y')

ECom_Data_copy = ECom_Data_copy.sort_values('Order_Date')

ECom_Data_copy.head()
# Out:
#                       Customer_uniq_id Region Order_Date  \
# 8905  a5235ac28d3d5487f54025f9d6b57433  North 2020-12-01
# 2370  0a59c85389ff071a82079f5d48e75c32   West 2020-12-01
# 2369  bfeaa950012011f135e8e6c2378170fd  North 2020-12-01
# 2368  9dab0a243bfa33deb22041344671f071  East  2020-12-01
# 2367  aae21c79de430cbaaf68fb05b86338ec   West 2020-12-01
#
#      Expected_Delivery_Date Delivered_Date  \
# 8905             04-12-2020     04-12-2020
# 2370             04-12-2020     04-12-2020
# 2369             04-12-2020     04-12-2020
# 2368             04-12-2020     04-12-2020
# 2367             04-12-2020     04-12-2020
#
#                                            product_name  \
# 8905  Aarushi Fashion Silk Striped Salwar Suit Dupat...
# 2370  Sovam International Peacock With Meena Art Sho...
# 2369              Allure Auto CM 1728 Car Mat Ford Figo
# 2368                SAC FA-SW-28X28 Showpiece  -  89 cm
# 2367  Allure Auto CM 1889 Car Mat Hyundai Fluidic Verna
#
# ...

# %% [markdown]
# - Converting Order_Date column from Object type to DataTime type.
# - Extracting only month_year from the above column for plotting on x-axis.

# %%
plt.figure(figsize=(20,15))
sns.lineplot(x=ECom_Data_copy.month_year, y=ECom_Data_copy.Revenue, hue=ECom_Data_copy.Region, ci=None, marker='*', markersize=15)
plt.title('Monthly Revenue of E-Commerce Company for each region', fontsize=20)
plt.xlabel('Time Period in Month-Year',fontsize=20)
plt.ylabel('Revenue by each region', fontsize=20)
plt.grid(which='major')
plt.xticks(rotation=45);

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# - North
#     - Best Performing month is **Aug-2021**
#     - Worst Performing month is **July-2021**
#
# - East
#     - Best Performing month is **Aug-2021**
#     - Worst Performing month is **Oct-2021**
#
# - West
#     - Best Performing month is **Mar-2021**
#     - Worst Performing month is **Oct-2021**
#
# - South
#     - Best Performing month is **Mar-2021**
#     - Worst Performing month is **May-2021**

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
