# %%
import pyforest

# %% [markdown]
# ### Problem 1

# %%
# Probability that a randomly chosen player would suffer an injury = Total no. of players who all are injured / Total no. of players in the data.
140/235

# %%
# Probability that a player is a forward or a winger = Probability that a player is a forward + Probability that a player is a winger
print(94+29)
print((94+29)/235)
# Out:
# 123
# 0.5234042553191489

# %%
# Probability that a randomly chosen player plays in a striker position and has foot injury = Total no. of players who are injured in striker position / Total no. of players in Striker position.
45/77
# Out:
# 0.5844155844155844

# %%
# Probability that a randomly chosen injured player is a striker = Total no. of players who are injured in striker position / Total no. of Injured players
45/145
# Out:
# 0.3103448275862069

# %%
# Probability that a randomly chosen injured player is either a forward or an attacking midfielder = Probability that a chosen injured player is Forward + Probability that a chosen injured player is Attacking midfielder.
print(56+24)
print((56+24)/145)
# Out:
# 80
# 0.5517241379310345

# %% [markdown]
# ### Problem 2
# * An independent research organization is trying to estimate the probability that an accident at a nuclear power plant will result in radiation leakage. The types of accidents possible at the plant are, fire hazards, mechanical failure, or human error. The research organization also knows that two or more types of accidents cannot occur simultaneously.
# <br></br>
# * According to the studies carried out by the organization, the probability of a radiation leak in case of a fire is 20%, the probability of a radiation leak in case of a mechanical 50%, and the probability of a radiation leak in case of a human error is 10%. The studies also showed the following;
# <br></br>
#     * The probability of a radiation leak occurring simultaneously with a fire is 0.1%.
#     * The probability of a radiation leak occurring simultaneously with a mechanical failure is 0.15%.
#     * The probability of a radiation leak occurring simultaneously with a human error is 0.12%.

# %% [markdown]
# * Given Probabilites from the question are,
#     * Probability of radiation leak in case of a fire is
#         * Prob_RadLeak_given_Fire = 0.2
#     * Probability of radiation leak in case of a Mechanical Failure is
#         * Prob_RadLeak_given_MechFail = 0.5
#     * Probability of radiation leak in case of a Human Error is
#         * Prob_RadLeak_given_HumanErr = 0.1
# <br></br>
# * Also given probabilites for,
#     * Probability of a radiation leak occurring simultaneously with a fire is
#         * Prob_RadLeak_and_Fire = 0.001
#     * Probability of a radiation leak occurring simultaneously with a Mechanical Failure is
#         * Prob_RadLeak_and_MechFail = 0.0015
#     * Probability of a radiation leak occurring simultaneously with a Human Error is
#         * Prob_RadLeak_and_HumanErr = 0.0012

# %%
Prob_RadLeak_given_Fire = 0.2
Prob_RadLeak_given_MechFail = 0.5
Prob_RadLeak_given_HumanErr = 0.1

Prob_RadLeak_and_Fire = 0.001
Prob_RadLeak_and_MechFail = 0.0015
Prob_RadLeak_and_HumanErr = 0.0012

# %% [markdown]
# * 2.1 What are the probabilities of a fire, a mechanical failure, and a human error respectively?

# %% [markdown]
# * We can use Conditional Probability to find out probabilites separately.
#     * P(A|B) = P(A and B) / P(B) => P(B) = P(A and B) / P(A|B)
#     * where, P(A|B) is Probability of event A given event B
#     * P(A and B) is Probability of event A and event B happening together
#     * P(B) is Probability of event B occuring.
# * Using above formula we can modify as,
#     * Prob_RadLeak_given_Fire = Prob_RadLeak_and_Fire / Prob_Fire
#         * Prob_Fire = Prob_RadLeak_and_Fire / Prob_RadLeak_given_Fire
#     * Prob_RadLeak_given_MechFail = Prob_RadLeak_and_MechFail / Prob_MechFail
#         * Prob_MechFail = Prob_RadLeak_and_MechFail / Prob_RadLeak_given_MechFail
#     * Prob_RadLeak_given_HumanErr = Prob_RadLeak_and_HumanErr / Prob_HumanErr
#         * Prob_HumanErr = Prob_RadLeak_and_HumanErr / Prob_RadLeak_given_HumanErr

# %%
Prob_Fire = Prob_RadLeak_and_Fire / Prob_RadLeak_given_Fire
Prob_MechFail = Prob_RadLeak_and_MechFail / Prob_RadLeak_given_MechFail
Prob_HumanErr = Prob_RadLeak_and_HumanErr / Prob_RadLeak_given_HumanErr

# %%
Prob_HumanErr = np.round(Prob_HumanErr,3)

print('The Probability of Fire is '+str(Prob_Fire))
print('The Probability of Mechanical Failure is '+str(Prob_MechFail))
print('The Probability of Human Error is '+str(Prob_HumanErr))
# Out:
# The Probability of Fire is 0.005
# The Probability of Mechanical Failure is 0.003
# The Probability of Human Error is 0.012

# %% [markdown]
# * 2.2 What is the probability of a radiation leak?

# %% [markdown]
# * Probability of radiation leak can be calculated using the law of total probability, which states that the probability of an event can be determined by summing the probabilities of that event occurring under each possible condition.
#     * Probability of Fire given Radiation Leak + Probability of Mechanical Error given Radiation Leak + Probability of Human Error given Radiation Leak = 1
#     * Prob_Fire_given_RadLeak + Prob_MechFail_given_RadLeak + Prob_HumanErr_given_RadLeak = 1

# %% [markdown]
# * We already know that,
#     * Prob_Fire_given_RadLeak = (Prob_RadLeak_given_Fire * Prob_Fire)/Prob_RadLeak
#     * Prob_MechFail_given_RadLeak = (Prob_RadLeak_given_MechFail * Prob_MechFail)/Prob_RadLeak
#     * Prob_HumanErr_given_RadLeak = (Prob_RadLeak_given_HumanErr * Prob_HumanErr)/Prob_RadLeak
# * (Prob_RadLeak_given_Fire * Prob_Fire)/Prob_RadLeak + (Prob_RadLeak_given_MechFail * Prob_MechFail)/Prob_RadLeak + (Prob_RadLeak_given_HumanErr * Prob_HumanErr)/Prob_RadLeak = 1
# * Prob_RadLeak = (Prob_RadLeak_given_Fire * Prob_Fire + Prob_RadLeak_given_MechFail * Prob_MechFail + Prob_RadLeak_given_HumanErr * Prob_HumanErr)

# %%
Prob_RadLeak = (Prob_RadLeak_given_Fire * Prob_Fire +
                Prob_RadLeak_given_MechFail * Prob_MechFail + 
                Prob_RadLeak_given_HumanErr * Prob_HumanErr)
        
print('The Probability of Radiation Leak is '+str(Prob_RadLeak))
# Out:
# The Probability of Radiation Leak is 0.0037

# %% [markdown]
# * 2.3 Suppose there has been a radiation leak in the reactor for which the definite cause is not known. What is the probability that it has been caused by:
#     * A Fire.
#     * A Mechanical Failure.
#     * A Human Error.

# %% [markdown]
# * Probability of Radiation leak caused by any one of Fire, Mechanical Failure, and Human Error
#     * Probabiliy of Fire given Radiation leak is
#         * Prob_Fire_given_RadLeak = (Prob_RadLeak_given_Fire * Prob_Fire)/Prob_RadLeak
#     * Probabiliy of Mechanical Failure given Radiation leak is
#         * Prob_MechFail_given_RadLeak = (Prob_RadLeak_given_MechFail * Prob_MechFail)/Prob_RadLeak
#     * Probabiliy of Human Error given Radiation leak is
#         * Prob_HumanErr_given_RadLeak = (Prob_RadLeak_given_HumanErr * Prob_HumanErr)/Prob_RadLeak

# %%
Prob_Fire_given_RadLeak = np.round((Prob_RadLeak_given_Fire * Prob_Fire)/Prob_RadLeak,3)
Prob_MechFail_given_RadLeak = np.round((Prob_RadLeak_given_MechFail * Prob_MechFail)/Prob_RadLeak,3)
Prob_HumanErr_given_RadLeak = np.round((Prob_RadLeak_given_HumanErr * Prob_HumanErr)/Prob_RadLeak,3)



print('The Probability of Fire given Radiation Leak is '+str(Prob_Fire_given_RadLeak))
print('The Probability of Mechanical Failure given Radiation Leak is '+str(Prob_MechFail_given_RadLeak))
print('The Probability of Human Error given Radiation Leak is '+str(Prob_HumanErr_given_RadLeak))
# Out:
# The Probability of Fire given Radiation Leak is 0.27
# The Probability of Mechanical Failure given Radiation Leak is 0.405
# The Probability of Human Error given Radiation Leak is 0.324

# %%
from scipy import stats

# %% [markdown]
# ### Problem 3
# * The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain; Answer the questions below based on the given information;

# %% [markdown]
# * From problem, given mean(mu=5) and standard deviation(sigma=1.5)
# * As, standard deviation of population is given, then we can use Z-test for this problem.

# %% [markdown]
# * 3.1 What proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm?

# %%
# Solution for 3.1

mu, sigma = 5, 1.5

x_bar = 3.17

test_stat = (x_bar - mu)/sigma
test_stat
# Out:
# -1.22

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
plt.title('Normal Distribution curve')
plt.show()

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
x1 = np.linspace(-4, test_stat, 50)
plt.fill_between(x1, stats.norm.pdf(x1, 0, 1), color='r')
plt.title('Normal Distribution curve - Area under Red Region')
plt.show()

# %% [markdown]
# * From above plot, we need to find out the probability or area under the shaded region for the given question that proportion less than 3.17 kg per sq cm
# * From below, we can see that the cumulative probability is just 11.1%

# %%
print('Cumulative Distribution Area under the Red Region is ' + str(np.round(stats.norm.cdf(test_stat),3)))
# Out:
# Cumulative Distribution Area under the Red Region is 0.111

# %% [markdown]
# * 3.2 What proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm.?

# %%
mu, sigma = 5, 1.5

x_bar = 3.6

test_stat = (x_bar - mu)/sigma
test_stat
# Out:
# -0.9333333333333332

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
plt.title('Normal Distribution curve')
plt.show()

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
x1 = np.linspace(test_stat, 4, 50)
plt.fill_between(x1, stats.norm.pdf(x1, 0, 1), color='r')
plt.title('Normal Distribution curve - Area under Red Region')
plt.show()

# %% [markdown]
# * From above plot, we need to find out the probability or area under the shaded region for the given question that proportion atleast 3.6 kg per sq cm
# * From below, we can see that the cumulative probability is 82.5% which is very high. We can assume that proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm is more.

# %%
print('Cumulative Distribution Area under the Red Region is ' + str(np.round(1 - stats.norm.cdf(test_stat),3)))
#1 - stats.norm.cdf(test_stat)
# Out:
# Cumulative Distribution Area under the Red Region is 0.825

# %% [markdown]
# * 3.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?

# %%
mu, sigma = 5, 1.5

x_bar1 = 5
test_stat1 = (x_bar1 - mu)/sigma
print(test_stat1)

x_bar2 = 5.5
test_stat2 = (x_bar2 - mu)/sigma
print(test_stat2)
# Out:
# 0.0
# 0.3333333333333333

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat1, c = 'r') 
plt.axvline(x = test_stat2, c = 'r')
plt.title('Normal Distribution curve')
plt.show()

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat1, c = 'r') 
plt.axvline(x = test_stat2, c = 'r') 
x1 = np.linspace(test_stat1, test_stat2, 50)
plt.fill_between(x1, stats.norm.pdf(x1, 0, 1), color='r')
plt.title('Normal Distribution curve - Area under Red Region')
plt.show()

# %% [markdown]
# * From above plot, we need to find out the probability or area under the shaded region for the given question that proportion between 5 and 5.5 kg per sq cm.
# * From below, we can see that the cumulative probability is 13.1% which is low because the interval between 5 and 5.5 kg per sq cm is very less.

# %%
#stats.norm.cdf(test_stat2) - stats.norm.cdf(test_stat1)
print('Cumulative Distribution Area under the Red Region is ' + str(np.round(stats.norm.cdf(test_stat2) - stats.norm.cdf(test_stat1),3)))
# Out:
# Cumulative Distribution Area under the Red Region is 0.131

# %% [markdown]
# * 3.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %%
mu, sigma = 5, 1.5

x_bar1 = 3
test_stat1 = (x_bar1 - mu)/sigma
print(test_stat1)

x_bar2 = 7.5
test_stat2 = (x_bar2 - mu)/sigma
print(test_stat2)
# Out:
# -1.3333333333333333
# 1.6666666666666667

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat1, c = 'r') 
plt.axvline(x = test_stat2, c = 'r')
plt.title('Normal Distribution curve')
plt.show()

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat1, c = 'r') 
plt.axvline(x = test_stat2, c = 'r') 
x1 = np.linspace(-4, test_stat1, 50)
x2 = np.linspace(test_stat2, 4, 50)
plt.fill_between(x1, stats.norm.pdf(x1, 0, 1), color='r')
plt.fill_between(x2, stats.norm.pdf(x2, 0, 1), color='r')
plt.title('Normal Distribution curve - Area under Red Region')
plt.show()

# %% [markdown]
# * From above plot, we need to find out the probability or area under the shaded region for the given question that proportion NOT between 3 and 7.5 kg per sq cm.
# * From below, we can see that the cumulative probability is 13.9% which is low because the interval NOT between 3 and 7.5 kg per sq cm is very less.

# %%
#stats.norm.cdf(test_stat1) + (1-stats.norm.cdf(test_stat2))
print('Cumulative Distribution Area under the Red Region is ' + str(np.round(stats.norm.cdf(test_stat1) + (1-stats.norm.cdf(test_stat2)),3)))
# Out:
# Cumulative Distribution Area under the Red Region is 0.139

# %% [markdown]
# ### Problem 4
# * Grades of the final examination in a training course are found to be normally distributed, with a mean of 77 and a standard deviation of 8.5. Based on the given information answer the questions below.

# %% [markdown]
# * From problem, given mean(mu=77) and standard deviation(sigma=8.5)
# * As, standard deviation of population is given, then we can use Z-test for this problem.

# %% [markdown]
# * 4.1 What is the probability that a randomly chosen student gets a grade below 85 on this exam?

# %%
# Solution for 4.1

mu, sigma = 77, 8.5
x_bar = 85

test_stat = (x_bar - mu)/sigma
test_stat
# Out:
# 0.9411764705882353

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
plt.title('Normal Distribution curve')
plt.show()

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
x1 = np.linspace(-4, test_stat, 50)
plt.fill_between(x1, stats.norm.pdf(x1, 0, 1), color='r')
plt.title('Normal Distribution curve - Area under Red Region')
plt.show()

# %% [markdown]
# * From above plot, we need to find out the probability or area under the shaded region for the given question that probability of grade less than 85.
# * From below, we can see that the cumulative probability is 82.7%

# %%
#stats.norm.cdf(test_stat)
print('Cumulative Distribution Area under the Red Region is ' + str(np.round(stats.norm.cdf(test_stat),3)))
# Out:
# Cumulative Distribution Area under the Red Region is 0.827

# %% [markdown]
# * 4.2 What is the probability that a randomly selected student scores between 65 and 87?

# %%
mu, sigma = 77, 8.5

x_bar1 = 65
test_stat1 = (x_bar1 - mu)/sigma
print(test_stat1)

x_bar2 = 87
test_stat2 = (x_bar2 - mu)/sigma
print(test_stat2)
# Out:
# -1.411764705882353
# 1.1764705882352942

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat1, c = 'r') 
plt.axvline(x = test_stat2, c = 'r')
plt.title('Normal Distribution curve')
plt.show()

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat1, c = 'r') 
plt.axvline(x = test_stat2, c = 'r') 
x1 = np.linspace(test_stat1, test_stat2, 50)
plt.fill_between(x1, stats.norm.pdf(x1, 0, 1), color='r')
plt.title('Normal Distribution curve - Area under Red Region')
plt.show()

# %% [markdown]
# * From above plot, we need to find out the probability or area under the shaded region for the given question that probability of scores between 65 and 87.
# * From below, we can see that the cumulative probability is 80.1%

# %%
#stats.norm.cdf(test_stat2) - stats.norm.cdf(test_stat1)
print('Cumulative Distribution Area under the Red Region is ' + str(np.round(stats.norm.cdf(test_stat2) - stats.norm.cdf(test_stat1),3)))
# Out:
# Cumulative Distribution Area under the Red Region is 0.801

# %%
stats.norm.cdf(65, loc=77, scale=8.5)
# Out:
# 0.07900962692369945

# %%
stats.norm.cdf(87, loc=77, scale=8.5)
# Out:
# 0.8802965606016053

# %%
0.8802965606016053 - 0.07900962692369945
# Out:
# 0.8012869336779058

# %% [markdown]
# * 4.3 What should be the passing cut-off so that 75% of the students clear the exam?

# %%
#stats.norm.ppf(0.25, loc=77, scale=8.5)
print('Passing cut-off so that 75% of the students clear the exam is ' + str(np.round(stats.norm.ppf(0.25, loc=77, scale=8.5),3)))
# Out:
# Passing cut-off so that 75% of the students clear the exam is 71.267

# %%
mu, sigma = 77, 8.5
x_bar = 71.267

test_stat = (x_bar - mu)/sigma
test_stat
# Out:
# -0.6744705882352946

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
plt.title('Normal Distribution curve')
plt.show()

# %%
x = np.linspace(-4, 4, 100) 
plt.plot(x, stats.norm.pdf(x, 0, 1)) 
plt.axvline(x = test_stat, c = 'r') 
x1 = np.linspace(test_stat, 4, 50)
plt.fill_between(x1, stats.norm.pdf(x1, 0, 1), color='r')
plt.title('Normal Distribution curve - Area under Red Region')
plt.show()

# %%
print('Cumulative Distribution Area under the Red Region is ' + str(np.round(1 - stats.norm.cdf(test_stat),3)))
# Out:
# Cumulative Distribution Area under the Red Region is 0.75

# %% [markdown]
# ### Problem 5
# * Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following (assuming a 5% significance level);

# %%
df_p5 = pd.read_csv('Zingaro_Company.csv')

df_p5.head()
# Out:
#    Unpolished   Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227

# %%
df_p5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unpolished            75 non-null     float64
#  1   Treated and Polished  75 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3 KB

# %%
df_p5.describe().T
# Out:
#                       count        mean        std         min         25%  \
# Unpolished             75.0  134.110527  33.041804   48.406838  115.329753
# Treated and Polished   75.0  147.788117  15.587355  107.524167  138.268300
#
#                              50%         75%         max
# Unpolished            135.597121  158.215098  200.161313
# Treated and Polished  145.721322  157.373318  192.272856

# %%
df_p5.skew()
# Out:
# Unpolished             -0.335652
# Treated and Polished    0.093365
# dtype: float64

# %%
df_p5.columns
# Out:
# Index(['Unpolished ', 'Treated and Polished'], dtype='object')

# %%
sns.displot(x=df_p5['Unpolished '], kde=True)
plt.title('Distribution Plot - Unpolished Data');

# %%
sns.displot(x=df_p5['Treated and Polished'], kde=True)
plt.title('Distribution Plot - Polished Data');

# %% [markdown]
# * 5.1 Earlier experience of Zingaro with this particular client is favorable as the stone surface was found to be of adequate hardness. However, Zingaro has reason to believe now that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?
# <br></br>
# * Hypothesis -
#     * H0 (Null Hypothesis) - Hardness index of unpolished stones >=150
#     * H1 (Alternative Hypothesis) - Hardness index of unpolished stones < 150
# <br></br>
# * Level of significance is 5% i.e. alpha=0.05
# * It is a One-Tailed test, so we need to divide p-value by 2 for comparing with alpha

# %%
ttest_1, p_val1 = stats.ttest_1samp(df_p5['Unpolished '], 150, alternative='less')
#print(ttest_1, p_val1)
print(f'For Unpolished data, test_statistic value is {np.round(ttest_1,3)} and P-value is {np.round(p_val1,5)}')
# Out:
# For Unpolished data, test_statistic value is -4.165 and P-value is 4e-05

# %% [markdown]
# * P value is too less than alpha i.e. 0.000042 (<<<0.05), Hence we have enough evidence to reject Null Hypothesis stating that Hardness index of unpolished stones is less than 150.
# * Zingaro has enough reason to believe that the unpolished stones will not be suitable for printing at 95% confidence.

# %% [markdown]
# * 5.2 Is the mean hardness of the polished and unpolished stones the same?
# <br></br>
# * Hypothesis -
#     * H0 (Null Hypothesis) - Mean hardness of polished stones = Mean hardness of unpolished stones
#     * H1 (Alternative Hypothesis) - Mean hardness of polished stones != Mean hardness of unpolished stones
# <br></br>
# * Level of significance is 5% i.e. alpha=0.05
# * It is a Two-Tailed test and 2 sample test.

# %%
ttest_2, p_val2 = stats.ttest_ind(df_p5['Unpolished '], df_p5['Treated and Polished'], alternative='two-sided')
print(f'From T-Test Independent samples, Test statistic value is {np.round(ttest_2,3)} and P-value is {np.round(p_val2,3)}')
# Out:
# From T-Test Independent samples, Test statistic value is -3.242 and P-value is 0.001

# %% [markdown]
# * P value is less than alpha i.e. 0.0015 (<0.05), Hence we have enough evidence to reject Null Hypothesis.
# * This concludes that Mean hardness of polished stones is not equal to the Mean hardness of unpolished stones.

# %% [markdown]
# ### Problem 6
# * Aquarius health club, one of the largest and most popular cross-fit gyms in the country has been advertising a rigorous program for body conditioning. The program is considered successful if the candidate is able to do more than 5 push-ups, as compared to when he/she enrolled in the program. Using the sample data provided can you conclude whether the program is successful? (Consider the level of Significance as 5%)

# %%
df_p6 = pd.read_csv('Aquarius_gym.csv')

df_p6.head()
# Out:
#    Sr no.  Before  After
# 0       1      39     44
# 1       2      25     25
# 2       3      39     39
# 3       4       6     13
# 4       5      40     44

# %%
df_p6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sr no.  100 non-null    int64
#  1   Before  100 non-null    int64
#  2   After   100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB

# %%
df_p6.describe().T
# Out:
#         count   mean        std   min    25%   50%    75%    max
# Sr no.  100.0  50.50  29.011492   1.0  25.75  50.5  75.25  100.0
# Before  100.0  26.94   8.806357   3.0  21.75  28.0  32.25   47.0
# After   100.0  32.49   8.779562  10.0  26.00  34.0  39.00   51.0

# %%
df_p6.skew()
# Out:
# Sr no.    0.000000
# Before   -0.271537
# After    -0.318966
# dtype: float64

# %%
sns.displot(x=df_p6.Before, kde=True)
plt.title('Distribution Plot - Before Joining club data');

# %%
sns.displot(x=df_p6.After, kde=True)
plt.title('Distribution Plot - After Joining club data');

# %% [markdown]
# * Note that this is a problem of the paired-t-test. Since the claim is that the training will make a difference of more than 5, the null and alternative hypotheses must be formed accordingly.
# <br></br>
# * Hypothesis -
#     * H0 (Null Hypothesis):        Push-ups after - Push-ups before <= 5
#     * H1 (Alternative Hypothesis): Push-ups after - Push-ups before > 5
# <br></br>
# * Level of significance is 5% i.e. alpha = 0.05
# * It is a One-Tailed - 2 sample test, so we need to divide p-value by 2 for comparing with alpha

# %%
ttest_3, p_val3 = stats.ttest_rel(df_p6.Before, df_p6.After)
print(ttest_3, p_val3/2)
print(f'From T-Test 2 sample analysis, Test Statistic value is {np.round(ttest_3,3)} and P-value is {np.round(p_val3/2,5)}')
# Out:
# -19.322619811082458 1.1460209626255983e-35
# From T-Test 2 sample analysis, Test Statistic value is -19.323 and P-value is 0.0

# %%
ttest_3, p_val3 = stats.ttest_rel(df_p6.Before, df_p6.After, alternative='greater')
print(ttest_3, 1-p_val3)
print(f'From T-Test 2 sample analysis, Test Statistic value is {np.round(ttest_3,3)} and P-value is {np.round(1-p_val3,5)}')
# Out:
# -19.322619811082458 0.0
# From T-Test 2 sample analysis, Test Statistic value is -19.323 and P-value is 0.0

# %% [markdown]
# * P value is too less than alpha or close to zero(0) i.e. 1.1 * 10-35 (<<<<0.05), Hence we have enough evidence to reject Null Hypothesis stating that Push-ups after - Pushups before >5.
# * This concludes that, Training will make a difference of more than 5 push-ups when compared to before start of the program.

# %% [markdown]
# ### Problem 7
# * Dental implant data: The hardness of metal implant in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as on the dentists who may favour one method above another and may work better in his/her favourite method. The response is the variable of interest.

# %%
df_p7 = pd.read_excel("Dental Hardness data.xlsx")

df_p7.head()
# Out:
#    Dentist  Method  Alloy    Temp  Response  Unnamed: 5  Unnamed: 6  \
# 0      1.0     1.0    1.0  1500.0     813.0         NaN         NaN
# 1      1.0     1.0    1.0  1600.0     792.0         NaN         NaN
# 2      1.0     1.0    1.0  1700.0     792.0         NaN         NaN
# 3      1.0     1.0    2.0  1500.0     907.0         NaN         NaN
# 4      1.0     1.0    2.0  1600.0     792.0         NaN         NaN
#
#                               Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  Anova: Two-Factor Without Replication        NaN        NaN         NaN
# 1                                    NaN        NaN        NaN         NaN
# 2                                SUMMARY      Count        Sum     Average
# 3                                      1          4       2315      578.75
# 4                                      1          4       2394       598.5
#
#      Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0            NaN         NaN         NaN
# ...

# %%
df_p7.tail()
# Out:
#      Dentist  Method  Alloy  Temp  Response  Unnamed: 5  Unnamed: 6  \
# 102      NaN     NaN    NaN   NaN       NaN         NaN         NaN
# 103      NaN     NaN    NaN   NaN       NaN         NaN         NaN
# 104      NaN     NaN    NaN   NaN       NaN         NaN         NaN
# 105      NaN     NaN    NaN   NaN       NaN         NaN         NaN
# 106      NaN     NaN    NaN   NaN       NaN         NaN         NaN
#
#     Unnamed: 7        Unnamed: 8 Unnamed: 9      Unnamed: 10  Unnamed: 11  \
# 102       Rows     513114.013889         89      5765.325999     0.778206
# 103    Columns  156164270.208333          3  52054756.736111  7026.375161
# 104      Error    1978064.041667        267      7408.479557          NaN
# 105        NaN               NaN        NaN              NaN          NaN
# 106      Total  158655448.263889        359              NaN          NaN
#
#     Unnamed: 12 Unnamed: 13
# 102    0.917216    1.315369
# 103         0.0    2.638412
# ...

# %%
df_p7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dentist      90 non-null     float64
#  1   Method       90 non-null     float64
#  2   Alloy        90 non-null     float64
#  3   Temp         90 non-null     float64
#  4   Response     90 non-null     float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   102 non-null    object
#  8   Unnamed: 8   100 non-null    object
#  9   Unnamed: 9   100 non-null    object
#  10  Unnamed: 10  99 non-null     object
#  11  Unnamed: 11  98 non-null     object
#  12  Unnamed: 12  3 non-null      object
#  13  Unnamed: 13  3 non-null      object
# dtypes: float64(7), object(7)
# memory usage: 11.8+ KB

# %%
df_p7.iloc[:92,:]
# Out:
#     Dentist  Method  Alloy    Temp  Response  Unnamed: 5  Unnamed: 6  \
# 0       1.0     1.0    1.0  1500.0     813.0         NaN         NaN
# 1       1.0     1.0    1.0  1600.0     792.0         NaN         NaN
# 2       1.0     1.0    1.0  1700.0     792.0         NaN         NaN
# 3       1.0     1.0    2.0  1500.0     907.0         NaN         NaN
# 4       1.0     1.0    2.0  1600.0     792.0         NaN         NaN
# ..      ...     ...    ...     ...       ...         ...         ...
# 87      5.0     3.0    2.0  1500.0     536.0         NaN         NaN
# 88      5.0     3.0    2.0  1600.0     405.0         NaN         NaN
# 89      5.0     3.0    2.0  1700.0     312.0         NaN         NaN
# 90      NaN     NaN    NaN     NaN       NaN         NaN         NaN
# 91      NaN     NaN    NaN     NaN       NaN         NaN         NaN
#
#                                Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
ddf = df_p7.iloc[:90,:5].copy()

ddf
# Out:
#     Dentist  Method  Alloy    Temp  Response
# 0       1.0     1.0    1.0  1500.0     813.0
# 1       1.0     1.0    1.0  1600.0     792.0
# 2       1.0     1.0    1.0  1700.0     792.0
# 3       1.0     1.0    2.0  1500.0     907.0
# 4       1.0     1.0    2.0  1600.0     792.0
# ..      ...     ...    ...     ...       ...
# 85      5.0     3.0    1.0  1600.0     483.0
# 86      5.0     3.0    1.0  1700.0     405.0
# 87      5.0     3.0    2.0  1500.0     536.0
# 88      5.0     3.0    2.0  1600.0     405.0
# 89      5.0     3.0    2.0  1700.0     312.0
#
# [90 rows x 5 columns]

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     float64
#  1   Method    90 non-null     float64
#  2   Alloy     90 non-null     float64
#  3   Temp      90 non-null     float64
#  4   Response  90 non-null     float64
# dtypes: float64(5)
# memory usage: 3.6 KB

# %%
ddf.describe().T
# Out:
#           count         mean         std     min     25%     50%     75%  \
# Dentist    90.0     3.000000    1.422136     1.0     2.0     3.0     4.0
# Method     90.0     2.000000    0.821071     1.0     1.0     2.0     3.0
# Alloy      90.0     1.500000    0.502801     1.0     1.0     1.5     2.0
# Temp       90.0  1600.000000   82.107083  1500.0  1500.0  1600.0  1700.0
# Response   90.0   741.777778  145.767845   289.0   698.0   767.0   824.0
#
#              max
# Dentist      5.0
# Method       3.0
# Alloy        2.0
# Temp      1700.0
# Response  1115.0

# %%
ddf.Dentist.value_counts()
# Out:
# 1.0    18
# 2.0    18
# 3.0    18
# 4.0    18
# 5.0    18
# Name: Dentist, dtype: int64

# %%
ddf.Method.value_counts()
# Out:
# 1.0    30
# 2.0    30
# 3.0    30
# Name: Method, dtype: int64

# %%
ddf.Alloy.value_counts()
# Out:
# 1.0    45
# 2.0    45
# Name: Alloy, dtype: int64

# %%
ddf.Temp.value_counts()
# Out:
# 1500.0    30
# 1600.0    30
# 1700.0    30
# Name: Temp, dtype: int64

# %%
ddf.Dentist = pd.Categorical(ddf.Dentist)
ddf.Method = pd.Categorical(ddf.Method)
ddf.Alloy = pd.Categorical(ddf.Alloy)
ddf.Temp = pd.Categorical(ddf.Temp)

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     category
#  1   Method    90 non-null     category
#  2   Alloy     90 non-null     category
#  3   Temp      90 non-null     category
#  4   Response  90 non-null     float64
# dtypes: category(4), float64(1)
# memory usage: 1.8 KB

# %%
sns.displot(x=ddf.Response, kde=True)
plt.title('Normal Distribution curve');

# %%
ddf.skew()
# Out:
# C:\Users\pranai\AppData\Local\Temp\ipykernel_21484\1624577375.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ddf.skew()
# Response   -1.058542
# dtype: float64

# %%
ddf_alloy1 = ddf[ddf.Alloy==1]
ddf_alloy2 = ddf[ddf.Alloy==2]

# %%
ddf_alloy1.value_counts()
# Out:
# Dentist  Method  Alloy  Temp    Response
# 1.0      1.0     1.0    1500.0  813.0       1
# 3.0      2.0     1.0    1700.0  613.0       1
#          3.0     1.0    1600.0  681.0       1
#                         1700.0  743.0       1
# 4.0      1.0     1.0    1500.0  792.0       1
#                         1600.0  743.0       1
#                         1700.0  762.0       1
#          2.0     1.0    1500.0  690.0       1
#                         1600.0  882.0       1
#                         1700.0  772.0       1
#          3.0     1.0    1500.0  493.0       1
#                         1600.0  707.0       1
#                         1700.0  289.0       1
# 5.0      1.0     1.0    1500.0  707.0       1
#                         1600.0  698.0       1
#                         1700.0  715.0       1
#          2.0     1.0    1500.0  803.0       1
#                         1600.0  665.0       1
#                         1700.0  752.0       1
# ...

# %%
ddf_alloy2.value_counts()
# Out:
# Dentist  Method  Alloy  Temp    Response
# 1.0      1.0     2.0    1500.0  907.0       1
# 3.0      2.0     2.0    1700.0  782.0       1
#          3.0     2.0    1600.0  824.0       1
#                         1700.0  681.0       1
# 4.0      1.0     2.0    1500.0  894.0       1
#                         1600.0  792.0       1
#                         1700.0  649.0       1
#          2.0     2.0    1500.0  813.0       1
#                         1600.0  870.0       1
#                         1700.0  858.0       1
#          3.0     2.0    1500.0  715.0       1
#                         1600.0  813.0       1
#                         1700.0  312.0       1
# 5.0      1.0     2.0    1500.0  772.0       1
#                         1600.0  1048.0      1
#                         1700.0  870.0       1
#          2.0     2.0    1500.0  824.0       1
#                         1600.0  933.0       1
#                         1700.0  835.0       1
# ...

# %%
from statsmodels.formula.api import ols 
from statsmodels.stats.anova import _get_covariance,anova_lm
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# * 7.1 Test whether there is any difference among the dentists on the implant hardness. State the null and alternative hypotheses. Note that both types of alloys cannot be considered together. You must state the null and alternative hypotheses separately for the two types of alloys.?

# %% [markdown]
# ### Null hypothesis (for Alloy 1): There is no difference among the dentists in terms of implant hardness for Alloy 1.
#
# ### Alternative hypothesis (for Alloy 1): There is a difference among the dentists in terms of implant hardness for Alloy 1.

# %% [markdown]
# ### Null hypothesis (for Alloy 2): There is no difference among the dentists in terms of implant hardness for Alloy 2.
#
# ### Alternative hypothesis (for Alloy 2): There is a difference among the dentists in terms of implant hardness for Alloy 2.

# %% [markdown]
# * 7.2 Before the hypotheses may be tested, state the required assumptions. Are the assumptions fulfilled? Comment separately on both alloy types.?

# %% [markdown]
# * Hypothesis Test for Shapiro Wilk Test for Alloy 1 -
#     * Null Hypothesis (for Alloy 1) - The population from which the sample is drawn follows a normal distribution.
#     * Alternative Hypothesis (for Alloy 1): The population from which the sample is drawn does not follow a normal distribution.

# %%
ss_t1, ss_p1 = stats.shapiro(ddf_alloy1['Response'])
ss_t1, ss_p1
# Out:
# (0.8304629921913147, 1.1945070582441986e-05)

# %%
print(f'The Test Statistic value is {np.round(ss_t1,3)} and P-value is {np.round(ss_p1,5)}')
# Out:
# The Test Statistic value is 0.83 and P-value is 1e-05

# %% [markdown]
# * We can conclude that P-value is 1e-05 (<<0.05), so we have enough evidence to Reject Null Hypothesis and consider that sample drawn for Alloy 1 does not follow a normal distribution.

# %% [markdown]
# * Hypothesis Test for Shapiro Wilk Test for Alloy 2 -
#     * Null Hypothesis (for Alloy 2) - The population from which the sample is drawn follows a normal distribution.
#     * Alternative Hypothesis (for Alloy 2): The population from which the sample is drawn does not follow a normal distribution.

# %%
ss_t2, ss_p2 = stats.shapiro(ddf_alloy2['Response'])
ss_t2, ss_p2
# Out:
# (0.887769341468811, 0.00040293222991749644)

# %%
print(f'The Test Statistic value is {np.round(ss_t2,3)} and P-value is {np.round(ss_p2,5)}')
# Out:
# The Test Statistic value is 0.888 and P-value is 0.0004

# %% [markdown]
# * We can conclude that P-value is 0.0004 (<<0.05), so we have enough evidence to Reject Null Hypothesis and consider that sample drawn for Alloy 2 does not follow a normal distribution.

# %% [markdown]
# * Hypothesis Test for Levene's Test for Alloy data -
#     * Null Hypothesis: The variances of the groups or samples being compared are equal for Alloy 1 and Alloy 2 data.
#     * Alternative Hypothesis: The variances of the groups or samples being compared are not equal for Alloy 1 and Alloy 2 data.

# %%
ss_t3, ss_p3 = stats.levene(ddf_alloy1['Response'], ddf_alloy2['Response'], center='mean')
ss_t3, ss_p3
# Out:
# (2.0847305562833265, 0.15232927745241737)

# %%
print(f'The Test Statistic value is {np.round(ss_t3,3)} and P-value is {np.round(ss_p3,5)}')
# Out:
# The Test Statistic value is 2.085 and P-value is 0.15233

# %% [markdown]
# * We can conclude that P-value is 0.152 (>0.05), so we have enough evidence for Fail to Reject Null Hypothesis and consider that variances of the groups or samples being compared are equal for Alloy 1 and Alloy 2 data.

# %% [markdown]
# * 7.3 Irrespective of your conclusion in 2, we will continue with the testing procedure. What do you conclude regarding whether implant hardness depends on dentists? Clearly state your conclusion. If the null hypothesis is rejected, is it possible to identify which pairs of dentists differ?

# %% [markdown]
# * Null hypothesis (for Alloy 1): There is no difference among the dentists in terms of implant hardness for Alloy 1.
#
# * Alternative hypothesis (for Alloy 1): There is a difference among the dentists in terms of implant hardness for Alloy 1.

# %%
formula_1 = 'Response ~ C(Dentist)'
model_1 = ols(formula_1,ddf_alloy1).fit()
ano_table_1 = anova_lm(model_1)
ano_table_1
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  1.977112  0.116567
# Residual    40.0  539593.555556  13489.838889       NaN       NaN

# %% [markdown]
# * P-value is 0.12 which is greater than alpha i.e. 0.05. Hence, we Fail to reject null hypothesis and consider there is no difference among the dentists in terms of implant hardness for Alloy 1.

# %%
sns.pointplot(x=ddf_alloy1.Dentist, y=ddf_alloy1.Response)
plt.title('Point Plot for Dentist vs Response (for Alloy 1)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
tukey_731 = pairwise_tukeyhsd(endog=ddf_alloy1['Response'], groups=ddf_alloy1['Dentist'], alpha=0.05) 
print(tukey_731)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#    1.0    2.0   11.3333 0.9996 -145.0423  167.709  False
#    1.0    3.0  -32.3333 0.9757  -188.709 124.0423  False
#    1.0    4.0  -68.7778 0.7189 -225.1535  87.5979  False
#    1.0    5.0 -122.2222 0.1889 -278.5979  34.1535  False
#    2.0    3.0  -43.6667 0.9298 -200.0423  112.709  False
#    2.0    4.0  -80.1111 0.5916 -236.4868  76.2646  False
#    2.0    5.0 -133.5556 0.1258 -289.9312  22.8201  False
#    3.0    4.0  -36.4444 0.9626 -192.8201 119.9312  False
#    3.0    5.0  -89.8889 0.4805 -246.2646  66.4868  False
#    4.0    5.0  -53.4444 0.8643 -209.8201 102.9312  False
# --------------------------------------------------------

# %% [markdown]
# * Null hypothesis (for Alloy 2): There is no difference among the dentists in terms of implant hardness for Alloy 2.
#
# * Alternative hypothesis (for Alloy 2): There is a difference among the dentists in terms of implant hardness for Alloy 2.

# %%
formula_2 = 'Response ~ C(Dentist)'
model_2 = ols(formula_2,ddf_alloy2).fit()
ano_table_2 = anova_lm(model_2)
ano_table_2
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  5.679791e+04  14199.477778  0.524835  0.718031
# Residual    40.0  1.082205e+06  27055.122222       NaN       NaN

# %% [markdown]
# * P-value is 0.72 which is very greater than alpha i.e. 0.05. Hence, we Fail to reject null hypothesis and consider there is no difference among the dentists in terms of implant hardness for Alloy 2.

# %%
sns.pointplot(x=ddf_alloy2.Dentist, y=ddf_alloy2.Response)
plt.title('Point Plot for Dentist vs Response (for Alloy 2)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
tukey_732 = pairwise_tukeyhsd(endog=ddf_alloy2['Response'], groups=ddf_alloy2['Dentist'], alpha=0.05) 
print(tukey_732)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#    1.0    2.0  -4.1111    1.0 -225.5687 217.3465  False
#    1.0    3.0 -36.5556 0.9895 -258.0131  184.902  False
#    1.0    4.0    -70.0 0.8941 -291.4576 151.4576  False
#    1.0    5.0 -90.1111 0.7724 -311.5687 131.3465  False
#    2.0    3.0 -32.4444 0.9933  -253.902 189.0131  False
#    2.0    4.0 -65.8889 0.9132 -287.3465 155.5687  False
#    2.0    5.0    -86.0 0.8008 -307.4576 135.4576  False
#    3.0    4.0 -33.4444 0.9925  -254.902 188.0131  False
#    3.0    5.0 -53.5556 0.9574 -275.0131  167.902  False
#    4.0    5.0 -20.1111  0.999 -241.5687 201.3465  False
# -------------------------------------------------------

# %% [markdown]
# * 7.4 Now test whether there is any difference among the methods on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which pairs of methods differ?

# %% [markdown]
# * Null hypothesis (for Alloy 1): There is no difference among the Methods in terms of implant hardness for Alloy 1.
#
# * Alternative hypothesis (for Alloy 1): There is a difference among the Methods in terms of implant hardness for Alloy 1.

# %%
formula_3 = 'Response ~ C(Method)'
model_3 = ols(formula_3,ddf_alloy1).fit()
ano_table_3 = anova_lm(model_3)
ano_table_3
# Out:
#              df         sum_sq       mean_sq         F    PR(>F)
# C(Method)   2.0  148472.177778  74236.088889  6.263327  0.004163
# Residual   42.0  497805.066667  11852.501587       NaN       NaN

# %% [markdown]
# * P-value is 0.004 which is lesser than alpha i.e. 0.05. Hence, we have enough evidence to reject null hypothesis and consider there is a difference among the Methods in terms of implant hardness for Alloy 1.

# %%
sns.pointplot(x=ddf_alloy1.Method, y=ddf_alloy1.Response)
plt.title('Point Plot for Method vs Response (for Alloy 1)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
tukey_741 = pairwise_tukeyhsd(endog=ddf_alloy1['Response'], groups=ddf_alloy1['Method'], alpha=0.05) 
print(tukey_741)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#    1.0    2.0   -6.1333  0.987  -102.714  90.4473  False
#    1.0    3.0    -124.8 0.0085 -221.3807 -28.2193   True
#    2.0    3.0 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %% [markdown]
# * Null hypothesis (for Alloy 2): There is no difference among the Methods in terms of implant hardness for Alloy 2.
#
# * Alternative hypothesis (for Alloy 2): There is a difference among the Methods in terms of implant hardness for Alloy 2.

# %%
formula_4 = 'Response ~ C(Method)'
model_4 = ols(formula_4,ddf_alloy2).fit()
ano_table_4 = anova_lm(model_4)
ano_table_4
# Out:
#              df    sum_sq        mean_sq        F    PR(>F)
# C(Method)   2.0  499640.4  249820.200000  16.4108  0.000005
# Residual   42.0  639362.4   15222.914286      NaN       NaN

# %% [markdown]
# * P-value is 0.000005 which is very lesser than alpha i.e. 0.05. Hence, we have enough evidence to reject null hypothesis and consider there is a difference among the Methods in terms of implant hardness for Alloy 2.

# %%
sns.pointplot(x=ddf_alloy2.Method, y=ddf_alloy2.Response)
plt.title('Point Plot for Method vs Response (for Alloy 2)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
tukey_742 = pairwise_tukeyhsd(endog=ddf_alloy2['Response'], groups=ddf_alloy2['Method'], alpha=0.05) 
print(tukey_742)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#    1.0    2.0     27.0 0.8212  -82.4546  136.4546  False
#    1.0    3.0   -208.8 0.0001 -318.2546  -99.3454   True
#    2.0    3.0   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %% [markdown]
# * 7.5 Now test whether there is any difference among the temperature levels on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which levels of temperatures differ?

# %% [markdown]
# * Null hypothesis (for Alloy 1): There is no difference among the Temperature levels in terms of implant hardness for Alloy 1.
#
# * Alternative hypothesis (for Alloy 1): There is a difference among the Temperature levels in terms of implant hardness for Alloy 1.

# %%
formula_5 = 'Response ~ C(Temp)'
model_5 = ols(formula_5,ddf_alloy1).fit()
ano_table_5 = anova_lm(model_5)
ano_table_5
# Out:
#             df         sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0   10154.444444   5077.222222  0.335224  0.717074
# Residual  42.0  636122.800000  15145.780952       NaN       NaN

# %% [markdown]
# * P-value is 0.72 which is very greater than alpha i.e. 0.05. Hence, we Fail to reject null hypothesis and consider there is no difference among the Temperature levels in terms of implant hardness for Alloy 1.

# %%
sns.pointplot(x=ddf_alloy1.Temp, y=ddf_alloy1.Response)
plt.title('Point Plot for Temp vs Response (for Alloy 1)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
tukey_751 = pairwise_tukeyhsd(endog=ddf_alloy1['Response'], groups=ddf_alloy1['Temp'], alpha=0.05) 
print(tukey_751)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper  reject
# ------------------------------------------------------
# 1500.0 1600.0 -15.6667 0.9353 -124.8436 93.5103  False
# 1500.0 1700.0 -36.6667 0.6953 -145.8436 72.5103  False
# 1600.0 1700.0    -21.0 0.8869  -130.177  88.177  False
# ------------------------------------------------------

# %% [markdown]
# * Null hypothesis (for Alloy 2): There is no difference among the Temperature levels in terms of implant hardness for Alloy 2.
#
# * Alternative hypothesis (for Alloy 2): There is a difference among the Temperature levels in terms of implant hardness for Alloy 2.

# %%
formula_6 = 'Response ~ C(Temp)'
model_6 = ols(formula_6,ddf_alloy2).fit()
ano_table_6 = anova_lm(model_6)
ano_table_6
# Out:
#             df        sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0  9.374893e+04  46874.466667  1.883492  0.164678
# Residual  42.0  1.045254e+06  24886.996825       NaN       NaN

# %% [markdown]
# * P-value is 0.17 which is very greater than alpha i.e. 0.05. Hence, we Fail to reject null hypothesis and consider there is no difference among the Temperature levels in terms of implant hardness for Alloy 2.

# %%
sns.pointplot(x=ddf_alloy2.Temp, y=ddf_alloy2.Response)
plt.title('Point Plot for Temp vs Response (for Alloy 2)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
tukey_752 = pairwise_tukeyhsd(endog=ddf_alloy2['Response'], groups=ddf_alloy2['Temp'], alpha=0.05) 
print(tukey_752)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
# 1500.0 1600.0  -26.3333 0.8915 -166.2828 113.6162  False
# 1500.0 1700.0 -107.2667 0.1624 -247.2162  32.6828  False
# 1600.0 1700.0  -80.9333 0.3475 -220.8828  59.0162  False
# --------------------------------------------------------

# %% [markdown]
# * 7.6 Consider the interaction effect of dentist and method and comment on the interaction plot, separately for the two types of alloys?

# %% [markdown]
# * Null hypothesis (for Alloy 1): There is no difference among the Interaction effect between Dentist and Method levels in terms of implant hardness for Alloy 1.
#
# * Alternative hypothesis (for Alloy 1): There is a difference among the Interaction effect between Dentist and Method levels in terms of implant hardness for Alloy 1.

# %%
formula_7 = 'Response ~ C(Dentist):C(Method)'
model_7 = ols(formula_7,ddf_alloy1).fit()
ano_table_7 = anova_lm(model_7)
ano_table_7
# Out:
#                         df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist):C(Method)  14.0  441097.244444  31506.946032  4.606728  0.000221
# Residual              30.0  205180.000000   6839.333333       NaN       NaN

# %% [markdown]
# * P-value is 0.000221 which is lesser than alpha i.e. 0.05. Hence, we have enough evidence to reject null hypothesis and consider there is a difference among the Interaction effect between Dentist and Method levels in terms of implant hardness for Alloy 1.

# %%
ddf_alloy1.head()
# Out:
#   Dentist Method Alloy    Temp  Response
# 0     1.0    1.0   1.0  1500.0     813.0
# 1     1.0    1.0   1.0  1600.0     792.0
# 2     1.0    1.0   1.0  1700.0     792.0
# 6     1.0    2.0   1.0  1500.0     782.0
# 7     1.0    2.0   1.0  1600.0     698.0

# %%
#str(ddf_alloy1['Dentist'][0])
ddf_alloy1_str = ddf_alloy1.copy()
#ddf_alloy1['Dentist'].str.cat(ddf_alloy1['Method'], sep=':')

# %%
ddf_alloy1_str['Dentist'] = ddf_alloy1_str['Dentist'].astype(str)
ddf_alloy1_str['Method'] = ddf_alloy1_str['Method'].astype(str)
ddf_alloy1_str.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 0 to 86
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   45 non-null     object
#  1   Method    45 non-null     object
#  2   Alloy     45 non-null     category
#  3   Temp      45 non-null     category
#  4   Response  45 non-null     float64
# dtypes: category(2), float64(1), object(2)
# memory usage: 2.8+ KB

# %%
ddf_alloy1_str['Dentist'].str.cat(ddf_alloy1_str['Method'], sep=':')
# Out:
# 0     1.0:1.0
# 1     1.0:1.0
# 2     1.0:1.0
# 6     1.0:2.0
# 7     1.0:2.0
# 8     1.0:2.0
# 12    1.0:3.0
# 13    1.0:3.0
# 14    1.0:3.0
# 18    2.0:1.0
# 19    2.0:1.0
# 20    2.0:1.0
# 24    2.0:2.0
# 25    2.0:2.0
# 26    2.0:2.0
# 30    2.0:3.0
# 31    2.0:3.0
# 32    2.0:3.0
# 36    3.0:1.0
# 37    3.0:1.0
# 38    3.0:1.0
# 42    3.0:2.0
# 43    3.0:2.0
# 44    3.0:2.0
# 48    3.0:3.0
# 49    3.0:3.0
# 50    3.0:3.0
# 54    4.0:1.0
# 55    4.0:1.0
# 56    4.0:1.0
# 60    4.0:2.0
# 61    4.0:2.0
# 62    4.0:2.0
# 66    4.0:3.0
# 67    4.0:3.0
# 68    4.0:3.0
# 72    5.0:1.0
# 73    5.0:1.0
# 74    5.0:1.0
# 78    5.0:2.0
# 79    5.0:2.0
# 80    5.0:2.0
# 84    5.0:3.0
# 85    5.0:3.0
# 86    5.0:3.0
# Name: Dentist, dtype: object

# %%
# str(ddf_alloy1['Dentist'])+':'+str(ddf_alloy1['Method'])
ddf_alloy1_str['Dentist:Method'] = ddf_alloy1_str['Dentist'].str.cat(ddf_alloy1_str['Method'], sep=':')
ddf_alloy1_str.head()
# Out:
#   Dentist Method Alloy    Temp  Response Dentist:Method
# 0     1.0    1.0   1.0  1500.0     813.0        1.0:1.0
# 1     1.0    1.0   1.0  1600.0     792.0        1.0:1.0
# 2     1.0    1.0   1.0  1700.0     792.0        1.0:1.0
# 6     1.0    2.0   1.0  1500.0     782.0        1.0:2.0
# 7     1.0    2.0   1.0  1600.0     698.0        1.0:2.0

# %%
tukey_761 = pairwise_tukeyhsd(endog=ddf_alloy1_str['Response'], groups=ddf_alloy1_str['Dentist:Method'], alpha=0.05) 
print(tukey_761)
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2  meandiff p-adj    lower     upper   reject
# -----------------------------------------------------------
# 1.0:1.0 1.0:2.0     -84.0 0.9933 -332.8283  164.8283  False
# 1.0:1.0 1.0:3.0  -63.3333 0.9996 -312.1617   185.495  False
# 1.0:1.0 2.0:1.0     -22.0    1.0 -270.8283  226.8283  False
# 1.0:1.0 2.0:2.0  -33.3333    1.0 -282.1617   215.495  False
# 1.0:1.0 2.0:3.0     -58.0 0.9999 -306.8283  190.8283  False
# 1.0:1.0 3.0:1.0  -91.6667 0.9853  -340.495  157.1617  False
# 1.0:1.0 3.0:2.0     -76.0 0.9975 -324.8283  172.8283  False
# 1.0:1.0 3.0:3.0  -76.6667 0.9972  -325.495  172.1617  False
# 1.0:1.0 4.0:1.0  -33.3333    1.0 -282.1617   215.495  False
# 1.0:1.0 4.0:2.0  -17.6667    1.0  -266.495  231.1617  False
# 1.0:1.0 4.0:3.0 -302.6667  0.007  -551.495  -53.8383   True
# 1.0:1.0 5.0:1.0  -92.3333 0.9844 -341.1617   156.495  False
# 1.0:1.0 5.0:2.0     -59.0 0.9998 -307.8283  189.8283  False
# ...

# %% [markdown]
# * The pairs which are interlinked here are (Dentist:Method),
#     * 1.0:1.0 with 4.0:3.0
#     * 1.0:1.0 with 5.0:3.0
#     * 1.0:2.0 with 5.0:3.0
#     * 1.0:3.0 with 5.0:3.0
#     * 2.0:1.0 with 4.0:3.0
#     * 2.0:1.0 with 5.0:3.0
#     * 2.0:2.0 with 4.0:3.0
#     * 2.0:2.0 with 5.0:3.0
#     * 2.0:3.0 with 5.0:3.0
#     * 3.0:1.0 with 5.0:3.0
#     * 3.0:2.0 with 5.0:3.0
#     * 3.0:3.0 with 5.0:3.0
#     * 4.0:1.0 with 4.0:3.0
#     * 4.0:1.0 with 5.0:3.0
#     * 4.0:2.0 with 4.0:3.0
#     * 4.0:2.0 with 5.0:3.0
#     * 5.0:1.0 with 5.0:3.0
#     * 5.0:2.0 with 5.0:3.0

# %% [markdown]
# * Null hypothesis (for Alloy 2): There is no difference among the Interaction effect between Dentist and Method levels in terms of implant hardness for Alloy 2.
#
# * Alternative hypothesis (for Alloy 2): There is a difference among the Interaction effect between Dentist and Method levels in terms of implant hardness for Alloy 2.

# %%
formula_8 = 'Response ~ C(Dentist):C(Method)'
model_8 = ols(formula_8,ddf_alloy2).fit()
ano_table_8 = anova_lm(model_8)
ano_table_8
# Out:
#                         df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist):C(Method)  14.0  753898.133333  53849.866667  4.194953  0.000482
# Residual              30.0  385104.666667  12836.822222       NaN       NaN

# %% [markdown]
# * P-value is 0.000482 which is lesser than alpha i.e. 0.05. Hence, we have enough evidence to reject null hypothesis and consider there is significant difference among the Interaction effect between Dentist and Method levels in terms of implant hardness for Alloy 2.

# %%
ddf_alloy2_str = ddf_alloy2.copy()
ddf_alloy2_str['Dentist'] = ddf_alloy2_str['Dentist'].astype(str)
ddf_alloy2_str['Method'] = ddf_alloy2_str['Method'].astype(str)
ddf_alloy2_str.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 3 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   45 non-null     object
#  1   Method    45 non-null     object
#  2   Alloy     45 non-null     category
#  3   Temp      45 non-null     category
#  4   Response  45 non-null     float64
# dtypes: category(2), float64(1), object(2)
# memory usage: 1.7+ KB

# %%
ddf_alloy2_str['Dentist'].str.cat(ddf_alloy2_str['Method'], sep=':')
# Out:
# 3     1.0:1.0
# 4     1.0:1.0
# 5     1.0:1.0
# 9     1.0:2.0
# 10    1.0:2.0
# 11    1.0:2.0
# 15    1.0:3.0
# 16    1.0:3.0
# 17    1.0:3.0
# 21    2.0:1.0
# 22    2.0:1.0
# 23    2.0:1.0
# 27    2.0:2.0
# 28    2.0:2.0
# 29    2.0:2.0
# 33    2.0:3.0
# 34    2.0:3.0
# 35    2.0:3.0
# 39    3.0:1.0
# 40    3.0:1.0
# 41    3.0:1.0
# 45    3.0:2.0
# 46    3.0:2.0
# 47    3.0:2.0
# 51    3.0:3.0
# 52    3.0:3.0
# 53    3.0:3.0
# 57    4.0:1.0
# 58    4.0:1.0
# 59    4.0:1.0
# 63    4.0:2.0
# 64    4.0:2.0
# 65    4.0:2.0
# 69    4.0:3.0
# 70    4.0:3.0
# 71    4.0:3.0
# 75    5.0:1.0
# 76    5.0:1.0
# 77    5.0:1.0
# 81    5.0:2.0
# 82    5.0:2.0
# 83    5.0:2.0
# 87    5.0:3.0
# 88    5.0:3.0
# 89    5.0:3.0
# Name: Dentist, dtype: object

# %%
ddf_alloy2_str['Dentist:Method'] = ddf_alloy2_str['Dentist'].str.cat(ddf_alloy2_str['Method'], sep=':')
ddf_alloy2_str.head()
# Out:
#    Dentist Method Alloy    Temp  Response Dentist:Method
# 3      1.0    1.0   2.0  1500.0     907.0        1.0:1.0
# 4      1.0    1.0   2.0  1600.0     792.0        1.0:1.0
# 5      1.0    1.0   2.0  1700.0     835.0        1.0:1.0
# 9      1.0    2.0   2.0  1500.0    1115.0        1.0:2.0
# 10     1.0    2.0   2.0  1600.0     835.0        1.0:2.0

# %%
tukey_762 = pairwise_tukeyhsd(endog=ddf_alloy2_str['Response'], groups=ddf_alloy2_str['Dentist:Method'], alpha=0.05) 
print(tukey_762)
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2  meandiff p-adj    lower     upper   reject
# -----------------------------------------------------------
# 1.0:1.0 1.0:2.0   95.3333  0.999 -245.5625  436.2292  False
# 1.0:1.0 1.0:3.0 -180.6667 0.8085 -521.5625  160.2292  False
# 1.0:1.0 2.0:1.0   37.6667    1.0 -303.2292  378.5625  False
# 1.0:1.0 2.0:2.0       5.0    1.0 -335.8958  345.8958  False
# 1.0:1.0 2.0:3.0 -140.3333 0.9635 -481.2292  200.5625  False
# 1.0:1.0 3.0:1.0  -63.3333    1.0 -404.2292  277.5625  False
# 1.0:1.0 3.0:2.0     -27.0    1.0 -367.8958  313.8958  False
# 1.0:1.0 3.0:3.0 -104.6667 0.9973 -445.5625  236.2292  False
# 1.0:1.0 4.0:1.0  -66.3333    1.0 -407.2292  274.5625  False
# 1.0:1.0 4.0:2.0    2.3333    1.0 -338.5625  343.2292  False
# 1.0:1.0 4.0:3.0 -231.3333 0.4686 -572.2292  109.5625  False
# 1.0:1.0 5.0:1.0      52.0    1.0 -288.8958  392.8958  False
# 1.0:1.0 5.0:2.0   19.3333    1.0 -321.5625  360.2292  False
# ...

# %% [markdown]
# * The pairs which are interlinked here are (Dentist:Method),
#     * 1.0:1.0 with 5.0:3.0
#     * 1.0:2.0 with 5.0:3.0
#     * 2.0:1.0 with 5.0:3.0
#     * 2.0:2.0 with 5.0:3.0
#     * 3.0:1.0 with 5.0:3.0
#     * 3.0:2.0 with 5.0:3.0
#     * 4.0:1.0 with 5.0:3.0
#     * 4.0:2.0 with 5.0:3.0
#     * 5.0:1.0 with 5.0:3.0
#     * 5.0:2.0 with 5.0:3.0

# %% [markdown]
# * 7.7 Now consider the effect of both factors, dentist, and method, separately on each alloy. What do you conclude? Is it possible to identify which dentists are different, which methods are different, and which interaction levels are different?

# %% [markdown]
# * Null hypothesis (for Alloy 1): There is no difference among the factors Dentist and Method levels in terms of implant hardness for Alloy 1.
#
# * Alternative hypothesis (for Alloy 1): There is a difference among the factors Dentist and Method levels in terms of implant hardness for Alloy 1.

# %%
formula_9 = 'Response ~ C(Dentist)+C(Method)'
model_9 = ols(formula_9,ddf_alloy1).fit()
ano_table_9 = anova_lm(model_9)
ano_table_9
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  2.591255  0.051875
# C(Method)    2.0  148472.177778  74236.088889  7.212522  0.002211
# Residual    38.0  391121.377778  10292.667836       NaN       NaN

# %% [markdown]
# * P value for Method is 0.0022 which is less than 0.05. Hence, we have enough evidence to reject null hypothesis and consider there's atleast one pair of Method means are different for Alloy 1.

# %%
sns.pointplot(x=ddf_alloy1.Dentist, y=ddf_alloy1.Response, hue=ddf_alloy1.Method)
plt.title('Point Plot for Dentist vs Response vs Method (for Alloy 1)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.pointplot(x=ddf_alloy1.Method, y=ddf_alloy1.Response, hue=ddf_alloy1.Dentist)
plt.title('Point Plot for Dentist vs Response vs Method (for Alloy 1)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
formula_9_1 = 'Response ~ C(Dentist)+C(Method)+C(Dentist):C(Method)'
model_9_1 = ols(formula_9_1,ddf_alloy1).fit()
ano_table_9_1 = anova_lm(model_9_1)
ano_table_9_1
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist):C(Method)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %% [markdown]
# * P value for Dentist, Method, and Interaction variable (Dentist:Method) are all less than 0.05. Hence, we can conclude that to reject null hypothesis and consider there is at least one pair of variables means are different for Alloy 1.

# %% [markdown]
# * Null hypothesis (for Alloy 2): There is no difference among the factors Dentist and Method levels in terms of implant hardness for Alloy 2.
#
# * Alternative hypothesis (for Alloy 2): There is a difference among the factors Dentist and Method levels in terms of implant hardness for Alloy 2.

# %%
formula_10 = 'Response ~ C(Dentist)+C(Method)'
model_10 = ols(formula_10,ddf_alloy2).fit()
ano_table_10 = anova_lm(model_10)
ano_table_10
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)   4.0   56797.911111   14199.477778   0.926215  0.458933
# C(Method)    2.0  499640.400000  249820.200000  16.295479  0.000008
# Residual    38.0  582564.488889   15330.644444        NaN       NaN

# %% [markdown]
# * P value for Method is 0.000008 which is too less than 0.05. Hence, we have enough evidence to reject null hypothesis and consider there's atleast one pair of Method means are different for Alloy 2.

# %%
sns.pointplot(x=ddf_alloy2.Dentist, y=ddf_alloy2.Response, hue=ddf_alloy2.Method)
plt.title('Point Plot for Dentist vs Response vs Method (for Alloy 2)');
# Out:
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\pranai\Anaconda3-2022\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
formula_10_1 = 'Response ~ C(Dentist)+C(Method)+C(Dentist):C(Method)'
model_10_1 = ols(formula_10_1,ddf_alloy2).fit()
ano_table_10_1 = anova_lm(model_10_1)
ano_table_10_1
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist):C(Method)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN

# %% [markdown]
# * P value for Method is 0.000004, which is only less than 0.05 when compared to Dentist (0.371833) and Interaction variable - Dentist : Method (0.093234). So we have enough evidence to reject null hypothesis stating that at least one of the pair means is different for Alloy 2.
